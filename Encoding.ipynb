# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohith20060521/Data-Science/blob/main/Encoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
df=pd.read_csv("/content/drive/MyDrive/loan_approved.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print(df.head())
print(df.info())
print(df.shape)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status (Approved)
# 0             1.0         Urban                      Y
# ...

# %%
df['Gender']=df['Gender'].fillna(df['Gender'].mode()[0])
df['Married']=df['Married'].fillna(df['Married'].mode()[0])
df['Dependents']=df['Dependents'].fillna(df['Dependents'].mode()[0])
df['Self_Employed']=df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])

# %%
df['LoanAmount']=df['LoanAmount'].fillna(df['LoanAmount'].mean())
df['Loan_Amount_Term']=df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mode()[0])
df['Credit_History']=df['Credit_History'].fillna(df['Credit_History'].mode()[0])

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status (Approved)
# 0             1.0         Urban                      Y
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID                   0
# Gender                    0
# Married                   0
# Dependents                0
# Education                 0
# Self_Employed             0
# ApplicantIncome           0
# CoapplicantIncome         0
# LoanAmount                0
# Loan_Amount_Term          0
# Credit_History            0
# Property_Area             0
# Loan_Status (Approved)    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Gender']=le.fit_transform(df['Gender'])

# %%
df['Married']=pd.get_dummies(df['Married'],dtype=int,drop_first=True)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Dependents']=le.fit_transform(df['Dependents'])

# %%
df['Education']=pd.get_dummies(df['Education'],dtype=int,drop_first=True)

# %%
df
# Out:
#       Loan_ID  Gender  Married  Dependents  Education Self_Employed  \
# 0    LP001002       1        0           0          0            No
# 1    LP001003       1        1           1          0            No
# 2    LP001005       1        1           0          0           Yes
# 3    LP001006       1        1           0          1            No
# 4    LP001008       1        0           0          0            No
# ..        ...     ...      ...         ...        ...           ...
# 609  LP002978       0        0           0          0            No
# 610  LP002979       1        1           3          0            No
# 611  LP002983       1        1           1          0            No
# 612  LP002984       1        1           2          0            No
# 613  LP002990       0        0           0          0           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0  146.412162             360.0
# ...

# %%
df['Self_Employed']=pd.get_dummies(df['Self_Employed'],dtype=int,drop_first=True)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Property_Area']=le.fit_transform(df['Property_Area'])

# %%
df['Loan_Status (Approved)']=pd.get_dummies(df['Loan_Status (Approved)'],dtype=int,drop_first=True)

# %%
df.head()
# Out:
#     Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0  LP001002       1        0           0          0              0
# 1  LP001003       1        1           1          0              0
# 2  LP001005       1        1           0          0              1
# 3  LP001006       1        1           0          1              0
# 4  LP001008       1        0           0          0              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History  Property_Area  Loan_Status (Approved)
# 0             1.0              2                       1
# ...

# %%
df.drop(columns="Loan_ID",inplace=True)

# %%
df.to_csv("/content/drive/MyDrive/new_loan_approved.csv")

# %%
df
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          0              0             5849
# 1         1        1           1          0              0             4583
# 2         1        1           0          0              1             3000
# 3         1        1           0          1              0             2583
# 4         1        0           0          0              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0             2900
# 610       1        1           3          0              0             4106
# 611       1        1           1          0              0             8072
# 612       1        1           2          0              0             7583
# 613       0        0           0          0              1             4583
#
# ...

# %% [markdown]
# 1.Identify outlier with help of histogram,boxplot,skewness.
#
# 2.Implement IQR or Z-score . If large no of outliers or high skew use IQR . else use Z-score.
#
# 3.If outlier percentage is more than 10% u cant delete outliers.
#
# 4.If u are keeping outliers u have to use decision based algorithms
#
# 5.If u keep outliers and u dont want to use decision based go for transformation techniques then use svm, knn or linear based algorithms
# (transformation convert non normal to normal)

# %%
s=(df['ApplicantIncome']-df['ApplicantIncome'].mean())/df['ApplicantIncome'].std()
print("z score: \n",s)
# Out:
# z score:
#  0      0.072931
# 1     -0.134302
# 2     -0.393427
# 3     -0.461686
# 4      0.097649
#          ...
# 609   -0.409796
# 610   -0.212383
# 611    0.436818
# 612    0.356773
# 613   -0.134302
# Name: ApplicantIncome, Length: 614, dtype: float64

# %%
df['CoapplicantIncome'].kurtosis()
# Out:
# np.float64(84.95638421103374)

# %%
df['CoapplicantIncome'].skew()
# Out:
# np.float64(7.491531216657306)

# %%
from sklearn.preprocessing import PowerTransformer
trans=PowerTransformer(method='yeo-johnson')
la_trans=trans.fit_transform(df[['CoapplicantIncome']])
# print(la_trans)
print(la_trans.shape)
# Out:
# (614, 1)

# %%
print("skewness: ", pd.Series(la_trans.reshape(614,)).skew())
print("kurtosis: ", pd.Series(la_trans.reshape(614,)).kurtosis())
# Out:
# skewness:  -0.14564645710551902
# kurtosis:  -1.8778432766544493

# %%
import seaborn as sns

# %%
sns.histplot(la_trans)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# # Correlation
# **In regression if u want to know association between numeric variable and target variable(also numeric)  use correlation coefficient**
