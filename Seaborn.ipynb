# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohith20060521/Data-Science/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set_theme(style="whitegrid")
tips=sns.load_dataset("tips")
iris=sns.load_dataset("iris")
print('Datasets loaded: tips (rows={}), iris (rows={})'.format(len(tips), len(iris)))
print(tips.head())
print(iris.head())
plt.show()
# Out:
# Datasets loaded: tips (rows=244), iris (rows=150)
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="day", palette="viridis")
plt.show()

# %%
sns.histplot(tips['total_bill'], kde=False)
plt.title('Histogram - Distribution of Total Bill')
plt.show()

# %%
sns.kdeplot(tips['total_bill'])
plt.title('KDE Plot - Smooth Distribution of Total Bill')
plt.show()# kde(kernel density estimation)

# %%
# Displot (Histogram + KDE)
sns.displot(tips['total_bill'], kde=True)
plt.title('Displot - Total Bill Distribution')
plt.show()

# %%
# Bar Plot - Average Tip by Gender
# ## 3. Categorical Plots (Why: compare groups/categories)

# - **Barplot** (`sns.barplot`): shows aggregate (mean) for categories.
# - **Countplot** (`sns.countplot`): shows counts of categorical values.
# - **Boxplot** (`sns.boxplot`): shows median, quartiles, and outliers.
# - **Violinplot** (`sns.violinplot`): boxplot + KDE.

# Use `hue` to split by another categorical variable.

sns.barplot(x='species', y='sepal_length', data=iris)
plt.title('Bar Plot - Species vs Sepal_length')
plt.show()

# %%
# Count Plot - Frequency of Days
sns.countplot(x='sex', data=tips)
plt.title('Count Plot - Frequency of species')
plt.show()

# %%
# Box Plot - Total Bill by Day
sns.boxplot(x='day', y='tip', data=tips)
plt.title('Box Plot - Total Bill by Day')
plt.show()

# %%
# Violin Plot - Distribution + Summary
sns.violinplot(x='day', y='tip', data=tips)
plt.title('Violin Plot - Total Bill by Day')
plt.show()

# %% [markdown]
# 4. Relationship Plots (Why: see how two numeric variables relate)
# Scatterplot (sns.scatterplot): point cloud to inspect correlation.
# Lineplot (sns.lineplot): trends over an ordered variable.
# Relplot (sns.relplot): figure-level interface for relational plots; supports faceting.

# %%
# Scatter Plot - Total Bill vs Tip
sns.scatterplot(x='total_bill', y='tip', data=tips, hue='sex')
plt.title('Scatter Plot - Total Bill vs Tip')
plt.show()

# %%
# Line Plot - Tip vs Party Size (useful for trend-like visuals)
sns.lineplot(x='size', y='tip', data=tips)
plt.title('Line Plot - Tip vs Party Size')
plt.show()

# %% [markdown]
# The selected code snippet col='day' in the sns.relplot function is used to create multiple plots, where each plot represents a unique value in the 'day' column of your dataset. This is known as faceting, and it helps visualize the relationship between total_bill and tip for each day of the week separately.

# %%
# Relplot with Facets
sns.relplot(x='total_bill', y='tip', hue='sex', col='day', data=tips)
plt.suptitle('Relplot - Tip vs Total Bill by Day & Gender', y=1.02)
plt.show()

# %% [markdown]
# Matrix & Correlation Plots (Why: inspect relationships between many variables)
# Heatmap (sns.heatmap): visualize correlation matrix or any 2D numerical table.
# Clustermap (sns.clustermap): heatmap + hierarchical clustering to find groups.

# %%
# Select only numeric columns
iris_num = iris.select_dtypes(include=['float', 'int'])

# Compute correlation
corr = iris_num.corr()

# Plot the heatmap
# annot=True displays the correlation values on each cell of the heatmap.
sns.heatmap(corr, annot=True,cmap='coolwarm')
plt.title("Heatmap - Correlation of Iris Features")
plt.show()

# %%
# Select only numeric columns (exclude 'species')
iris_num = iris.select_dtypes(include=['float', 'int'])

# Compute correlation matrix
corr = iris_num.corr()

# Create the clustermap
sns.clustermap(corr, cmap='coolwarm', annot=True)
plt.suptitle('Clustermap - Grouped Correlations (Numeric Only)', y=1.02)
plt.show()

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
path="/content/drive/MyDrive/Customer.csv"
df=pd.read_csv(path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Visualization Task (seaborn Matplotlib)
#
# A. Numerical Columns (Item_price, connected_handling_time, CSAT Score)
#
# “Show me the distribution of Item_price.” → Histogram
#
# “How does CSAT Score vary overall?” → Boxplot
#
# “What is the spread of connected_handling_time values?” → Histogram + boxplot
#
# “Can I see a pie chart of CSAT scores by their value?” → Pie chart
#
# “What are the most common price ranges for items?” → Binned bar chart
#
# B. Categorical Columns (channel_name, category, Sub-category, Agent Shift, Tenure Bucket)
#
# “How many tickets come from each channel_name?” → Bar chart
#
# “Which category has the highest number of tickets?” → Bar chart (sorted)
#
# “Show me the distribution of tickets by Agent Shift.” → Pie chart
#
# “What are the top 10 Sub-category values?” → Horizontal bar chart
#
# “How many tickets belong to each Tenure Bucket?” → Bar chart
#
# A. Numerical vs Numerical
#
# “Is there a relationship between Item_price and CSAT Score?” → Scatter plot
#
# “How does connected_handling_time affect CSAT Score?” → Scatter plot + trend line
#
# “Show me density or clusters of Item_price vs connected_handling_time.” → Hexbin plot
#
# B. Numerical vs Categorical
#
# “What is the average CSAT Score per channel_name?” → Grouped bar chart
#
# “Show distribution of Item_price per category.” → Multiple boxplots
#
# “How does connected_handling_time vary by Agent Shift?” → Boxplot
#
# “Show mean and variability of Item_price across top 5 Product_category.” → Error bar plot
#
# “How do CSAT scores differ across Tenure Bucket?” → Bar chart
#
# C. Categorical vs Categorical
#
# “Show the number of tickets by channel_name and category together.” → Stacked bar chart
#
# “How does Agent Shift distribution differ across category?” → Stacked bar or grouped bar chart
#
# (Using order_date_time, Issue_reported at, Survey_response_Date)
#
# “How many tickets were created per day?” → Line plot
#
# “Show daily trend of average CSAT Score.” → Line plot (rolling average optional)
#
# “Plot number of issues reported weekly.” → Bar chart (aggregated)
#
# “What is the monthly pattern of ticket volume?” → Line plot with month aggregation
#
# “How does ticket volume differ by channel_name over time?” → Multi-line plot
#
# “Show the time lag between Issue_reported at and issue_responded.” → Line or scatter plot (response time trend)
#
# “Show the volume of resolved issues over time.” → Line plot
#
# “What is the peak hour or day for incoming tickets?” → Bar chart (hourly/daily distribution)

# %%
print(df.head())
print(df.shape)
print(df.info())
# Out:
#                               Unique id channel_name         category  \
# 0  7e9ae164-6a8b-4521-a2d4-58f7c9fff13f      Outcall  Product Queries
# 1  b07ec1b0-f376-43b6-86df-ec03da3b2e16      Outcall  Product Queries
# 2  200814dd-27c7-4149-ba2b-bd3af3092880      Inbound    Order Related
# 3  eb0d3e53-c1ca-42d3-8486-e42c8d622135      Inbound          Returns
# 4  ba903143-1e54-406c-b969-46c52f92e5df      Inbound     Cancellation
#
#                    Sub-category Customer Remarks  \
# 0                Life Insurance              NaN
# 1  Product Specific Information              NaN
# 2             Installation/demo              NaN
# 3        Reverse Pickup Enquiry              NaN
# 4                    Not Needed              NaN
#
#                                Order_id order_date_time Issue_reported at  \
# 0  c27c9bb4-fa36-4140-9f1f-21009254ffdb             NaN  01/08/2023 11:13
# 1  d406b0c7-ce17-4654-b9de-f08d421254bd             NaN  01/08/2023 12:52
# ...

# %%
df.isnull().sum()
# Out:
# Unique id                  0
# channel_name               0
# category                   0
# Sub-category               0
# Customer Remarks           0
# Order_id                   0
# order_date_time            0
# Issue_reported at          0
# issue_responded            0
# Survey_response_Date       0
# Customer_City              0
# Product_category           0
# Item_price                 0
# connected_handling_time    0
# Agent_name                 0
# Supervisor                 0
# Manager                    0
# Tenure Bucket              0
# Agent Shift                0
# CSAT Score                 0
# dtype: int64

# %%
cust=df.select_dtypes(include=['float','int'])
df.fillna(cust.mean(),inplace=True)
for col in df.select_dtypes(include='object').columns:
    if df[col].isnull().any():
        df[col].fillna(df[col].mode()[0], inplace=True)
print(df)
# Out:
#                                   Unique id channel_name         category  \
# 0      7e9ae164-6a8b-4521-a2d4-58f7c9fff13f      Outcall  Product Queries
# 1      b07ec1b0-f376-43b6-86df-ec03da3b2e16      Outcall  Product Queries
# 2      200814dd-27c7-4149-ba2b-bd3af3092880      Inbound    Order Related
# 3      eb0d3e53-c1ca-42d3-8486-e42c8d622135      Inbound          Returns
# 4      ba903143-1e54-406c-b969-46c52f92e5df      Inbound     Cancellation
# ...                                     ...          ...              ...
# 85902  505ea5e7-c475-4fac-ac36-1d19a4cb610f      Inbound   Refund Related
# 85903  44b38d3f-1523-4182-aba2-72917586647c      Inbound    Order Related
# 85904  723bce2c-496c-4aa8-a64b-ca17004528f0      Inbound    Order Related
# 85905  707528ee-6873-4192-bfa9-a491f1c08ab5      Inbound         Feedback
# 85906  07c7a878-0d5a-42e0-97ef-de59abec0238      Inbound          Returns
#
#                        Sub-category                          Customer Remarks  \
# ...

# %%
sns.histplot(df['Item_price'], kde=False)
plt.title('Histogram - Distribution of Total Bill')
plt.show()

# %%
sns.boxplot(x='CSAT Score' ,data=df)
plt.title('Box Plot - Total CSAT Score ')
plt.show()

# %%
sns.violinplot(x='connected_handling_time', data=df)
plt.title('Violin Plot - connected_handling_time')
plt.show()

# %%
plt.pie(df['CSAT Score'].value_counts(), labels=df['CSAT Score'].unique(), autopct='%1.1f%%')
plt.title('Pie Chart - CSAT Score')
plt.show()

# %%
# How many tickets come from each channel_name?” → Bar chart

plt.bar(df['channel_name'].unique(),df['channel_name'].value_counts())
plt.title('Bar Plot - Frequency of channel_name')
plt.show()
